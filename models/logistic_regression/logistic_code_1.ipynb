# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsikeka/data_science/blob/main/models/logistic_regression/logistic_code_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logistic regression-1

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/sample_data/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='*', color='red')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
model =  LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0])

# %%
X_test
# Out:
# (    age
#  16   25
#  1    25
#  13   29,
#  16    1
#  1     0
#  13    0
#  Name: bought_insurance, dtype: int64)

# %%
Y_test
# Out:
# 16    1
# 1     0
# 13    0
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test,Y_test)
# Out:
# 0.6666666666666666
